# %% [markdown]
# ## Method 1

# %%
from app import *
# Out:
# 2023-06-02 01:55:58.975803: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
tissue_dir = './Data/10X/V1_Adult_Mouse_Brain_Coronal_Section_2/'
Tgenes=['Rbfox3', 'Lamp5']

# %%
demask_image_t, demask_image_t_g, tsimg1_, conv_spatial_images_ = \
    merge(tissue_dir, Tgenes, num_iter = 32, is_cut_bg = True)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /home/res1/anaconda3/envs/jeongbin_interactive/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version. Use is_categorical_dtype instead.
#   if not is_categorical(df_full[k]):
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# {'spot_diameter_fullres': 178.44077999999996, 'tissue_hires_scalef': 0.08250825, 'fiducial_diameter_fullres': 288.25050000000005, 'tissue_lowres_scalef': 0.024752475}
# /home/hychoi/DATA1/DB_Spatial/interactive_t-SNE/_imagizer_mask.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imcoord_tissue.barcodes = [bname + barcode_tag for bname in imcoord_tissue.barcodes]
# /home/res1/anaconda3/envs/jeongbin_interactive/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version. Use is_categorical_dtype instead.
#   if not is_categorical(df_full[k]):
# /home/hychoi/DATA1/DB_Spatial/interactive_t-SNE/_imagizer_mask.py:63: FutureWarning: `draw.circle` is deprecated in favor of `draw.disk`.`draw.circle` will be removed in version 0.19
#   r, c = draw.circle(rr, cc, radius = radius)
# 2023-06-02 01:56:00.498721: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-06-02 01:56:00.499253: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-06-02 01:56:00.547654: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-02 01:56:00.548139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:09:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-06-02 01:56:00.548219: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-02 01:56:00.549163: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:0a:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-06-02 01:56:00.549191: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-06-02 01:56:00.551367: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2023-06-02 01:56:00.551392: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2023-06-02 01:56:00.552415: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-06-02 01:56:00.552554: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-06-02 01:56:00.552592: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/res1/.local/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-06-02 01:56:00.552979: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2023-06-02 01:56:00.553065: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2023-06-02 01:56:00.553071: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-06-02 01:56:00.553397: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-02 01:56:00.554110: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-06-02 01:56:00.554120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-06-02 01:56:00.554123: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]
# 2023-06-02 01:56:02.896778: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-06-02 01:56:02.925199: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3393925000 Hz
# number of features: 2
# ...1/2
# number of features: 2
# ...1/2
# number of features: 2
# ...1/2

# %%
plt.imshow(demask_image_t[0])

# %%
plt.imshow(demask_image_t[1])

# %% [markdown]
# ## Method 2

# %%
f = h5py.File("SuperST.hdf5", 'r')

# %%
dset1 = f['demask_image_t']
dset2 = f['demask_image_t_g']
dset3 = f['tsimg1_']
dset4 = f['conv_spatial_images_']

# %%
plt.imshow(dset1[0])

# %%
plt.imshow(dset1[1])
